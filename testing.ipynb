# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from wt.core import load_cards, schema, cards_to_probabilities

# %%
cards = load_cards('./data/cards')

# %%
schema['rarity']
# Out:
# {'common': 1, 'rare': 3, 'uncommon': 2}

# %%
list(schema['rarity'].keys())
# Out:
# ['common', 'uncommon', 'rare']

# %%
cards
# Out:
#       class  cost                                        description  \
# 0   generic     3  Deal 4 Physical Damage to an adjacent unit.\nI...
# 1      mage    -1  Your next Magical Attack deals X additional da...
# 2   generic     5  Range 2.\nIf you use this card in response to ...
# 3   generic     4  Range 2.\nDeal 2 damage to target unit.\nIf an...
# 4   generic     4  Range 2.\nDeal 2 damage to target unit.\nDeal ...
# 5     rogue     3  Deal 4 damage to an adjacent enemy.\nIf an all...
# 6   generic     4  Range 2.\nDiscard your hand.\nDeal damage to t...
# 7   generic     2            Range 2.\nDeal 2 damage to target unit.
# 8     rogue     3  Range 2.\nTarget unit cannot move until the st...
# 9   generic     3  Deal 3 damage to an adjacent unit.\nShuffle on...
# 10    rogue     3  As an additional cost to playing this card, yo...
# 11  generic     0  Deal damage to an adjacent unit equal to your ...
# 12    rogue     3                    Draw 3 cards.\nDiscard 2 cards.
# ...

# %%
r, u, c = cards_to_probabilities(cards)

# %%
c
# Out:
# array(['Arrow Splitter', 'Backstab', 'Blast', 'Bolas', 'Burning Grasp',
#        'Cloak and Dagger', 'Clumsy Acquisation', 'Cold Ray',
#        'Combo Cutter', 'Coup De Grace', 'Cut', 'Cyclone',
#        'Draining Strike', 'Dusty Coin', 'Earthmines', 'Earthshaker',
#        'Feint', 'Firebolt', 'First Strike', 'Flashfire Scroll',
#        'Flurry of Strikes', 'Gust', 'Hammerspace', 'Hasty Disposal',
#        'Hidden Pockets', 'Jar of Poison', 'Knife Collection', 'Lucky Coin',
#        'Magic Missile', 'Metal Rain', 'Mind Blast', 'Obliterate',
#        'Piercing Arrow', 'Quick Strike', 'Razor Wind', 'Riposte',
#        'Shield Bash', 'Shoot', 'Slice', 'Stab', 'Stronger Dose',
#        "Thieve's Handbook", 'Toxic Strike', 'Weakening Agent', 'Whirlwind',
#        'a name'], dtype=object)

# %%
from wt.core import __batch_prepare_card_uuids_and_versions

# %%
__batch_prepare_card_uuids_and_versions('./data/cards')
